# %% [markdown]
# # Telecome Data Overview analysis

# %%
# Import basic libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Get working Directory
import os, sys

current_dir = os.getcwd()
# Get the parent directory
parent_dir = os.path.dirname(current_dir)
# Insert the path to the parent directory
sys.path.insert(0, parent_dir)

# %%
from scripts.Telecom_data_EDA import TelecomEDA
from scripts.data_visualization import DataVisualization

# %% [markdown]
# **Import Preprocessed and Cleaned Data**

# %%
data = pd.read_csv(r"C:\Users\liulj\Desktop\KAIM\KAIM-Week-2\Telecom-Data-Analysis\data\preprocessed_telecom_data.csv")

# %%
telecom_eda = TelecomEDA(data)
data_visualization = DataVisualization(data)

# %% [markdown]
# ### Identifying Top three handsets

# %%
# Identify Top handset type
top_10_handset = telecom_eda.top_handset_type()
top_10_handset
# Out:
# Top 10 Handsets:
# Handset Type
# Apple iPhone 6S (A1688)         8110
# Apple iPhone 6 (A1586)          7667
# undefined                       7267
# Apple iPhone 7 (A1778)          5120
# Apple iPhone Se (A1723)         4526
# Apple iPhone 8 (A1905)          4161
# Apple iPhone Xr (A2105)         3700
# Samsung Galaxy S8 (Sm-G950F)    3563
# Huawei B528S-23A                3345
# Samsung Galaxy A5 Sm-A520F      3142
# Name: count, dtype: int64

# %% [markdown]
# **Plot Top 10 Handset**

# %%
data_visualization.top_hand_set_plot()

# %% [markdown]
# **Top Three Handset Manufacturer**

# %%
top_manufacturers = telecom_eda.top_3_handset_manufacturer()
top_manufacturers
# Out:
# Top 3 Manufacturers:
# Handset Manufacturer
# Apple      49672
# Samsung    33132
# Huawei     13339
# Name: count, dtype: int64

# %% [markdown]
# **Plot Top Three Manufacturers**

# %%
data_visualization.top_manufacturer_handset_plot()

# %% [markdown]
# ## Aggregate Session

# %%
aggregate_session = telecom_eda.aggregate_session()
aggregate_session
# Out:
# Aggregated User Data:
#               Social Media DL (Bytes)  Social Media UL (Bytes)  \
# Bearer Id
# 6.917538e+18                2404741.0                   2410.0
# 6.917538e+18                2478607.0                  11936.0
# 6.917538e+18                 944612.0                   2827.0
# 6.917538e+18                1817239.0                  19827.0
# 6.917538e+18                1867318.0                  18928.0
#
#               Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# Bearer Id
# 6.917538e+18          5791591.0          2871336.0          782388.0
# 6.917538e+18          3605446.0          2825198.0          446376.0
# 6.917538e+18         10373157.0            56392.0          128003.0
# 6.917538e+18           269988.0          3696393.0         3191192.0
# 6.917538e+18          1689296.0           195216.0          740633.0
#
#               Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# Bearer Id
# ...

# %%
user_engagemnt_anaysis = telecom_eda.user_engagement_analysis()
user_engagemnt_anaysis
# Out:
# Cluster Summary:
#          Total Duration  Total Data Volume
# Cluster
# 0         202711.977063       7.241691e+08
# 1          70125.803766       7.115323e+08
# 2          96209.291873       2.737711e+08
